# %%
# -*- coding: utf-8 -*-
import dataiku
import pandas as pd, numpy as np

# %%
# Read recipe inputs
transactions_known = dataiku.Dataset("transactions_known")
df = transactions_known.get_dataframe(limit=10000)

# %%
df.head()
# Out:
#    transaction_id  authorized_flag        purchase_date purchase_date_parsed  purchase_year  purchase_month  purchase_day  purchase_dow  purchase_weekend  purchase_hour          card_id      merchant_id  merchant_category_id item_category  purchase_amount  signature_provided card_first_active_month card_first_active_month_parsed  days_active   card_reward_program  card_latitude  card_longitude  card_fico_score  card_age merchant_subsector_description  merchant_latitude  merchant_longitude       merchant_location  merchant_cardholder_distance  merchant_state merchant_state_enName           card_location  card_state card_state_enName
# 0           99002                1  2017-07-14 11:44:11  2017-07-14 11:44:11           2017               7            14             5                 0             11  C_ID_b7b65edd42  M_ID_83d9e56d89                   333             B          1300.61                   1                 2017-03                     2017-03-01          135  dining_entertainment         42.124        -123.022              849        82                      insurance             42.883             -91.755   POINT(-91.755 42.883)                       1584.37            Iowa                  Iowa  POINT(-123.022 42.124)      Oregon            Oregon
# 1           99004                1  2017-07-14 11:47:32  2017-07-14 11:47:32           2017               7            14             5                 0             11  C_ID_9881fa2036  M_ID_1fcdbdeb5d                   705             D            24.99                   0                 2016-10                     2016-10-01          286             cash_back         34.703        -105.031              577        22                      groceries             47.837            -100.707  POINT(-100.707 47.837)                        934.45    North Dakota          North Dakota  POINT(-105.031 34.703)  New Mexico        New Mexico
# 2           99005                1  2017-07-14 11:47:53  2017-07-14 11:47:53           2017               7            14             5                 0             11  C_ID_385ea322b6  M_ID_735750b582                   434             D           660.28                   0                 2017-01                     2017-01-01          194             cash_back         32.538         -98.207              638        62                        flights             32.880             -80.740     POINT(-80.74 32.88)                       1014.61  South Carolina        South Carolina   POINT(-98.207 32.538)       Texas             Texas
# 3           99006                1  2017-07-14 11:48:28  2017-07-14 11:48:28           2017               7            14             5                 0             11  C_ID_f575dcabce  M_ID_068f58a2dc                   884             B           332.72                   0                 2016-06                     2016-06-01          408             cash_back         41.296        -117.240              746        23           consumer electronics             43.942            -121.051  POINT(-121.051 43.942)                        266.35          Oregon                Oregon   POINT(-117.24 41.296)      Nevada            Nevada
# 4           99015                1  2017-07-14 11:53:58  2017-07-14 11:53:58           2017               7            14             5                 0             11  C_ID_4a5e1f3984  M_ID_61ffc71e45                   419             A           444.21                   0                 2016-10                     2016-10-01          286             cash_back         45.098        -119.125              314        39                            NaN                NaN                 NaN                     NaN                           NaN             NaN                   NaN  POINT(-119.125 45.098)      Oregon            Oregon

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 34 columns):
# transaction_id                    10000 non-null int64
# authorized_flag                   10000 non-null int64
# purchase_date                     10000 non-null object
# purchase_date_parsed              10000 non-null datetime64[ns]
# purchase_year                     10000 non-null int64
# purchase_month                    10000 non-null int64
# purchase_day                      10000 non-null int64
# purchase_dow                      10000 non-null int64
# purchase_weekend                  10000 non-null int64
# purchase_hour                     10000 non-null int64
# card_id                           10000 non-null object
# merchant_id                       10000 non-null object
# merchant_category_id              10000 non-null int64
# item_category                     10000 non-null object
# purchase_amount                   10000 non-null float64
# signature_provided                10000 non-null int64
# card_first_active_month           10000 non-null object
# card_first_active_month_parsed    10000 non-null datetime64[ns]
# days_active                       10000 non-null int64
# card_reward_program               10000 non-null object
# card_latitude                     10000 non-null float64
# card_longitude                    10000 non-null float64
# card_fico_score                   10000 non-null int64
# card_age                          10000 non-null int64
# merchant_subsector_description    9881 non-null object
# merchant_latitude                 9881 non-null float64
# merchant_longitude                9881 non-null float64
# merchant_location                 9881 non-null object
# merchant_cardholder_distance      9881 non-null float64
# merchant_state                    9881 non-null object
# merchant_state_enName             9881 non-null object
# card_location                     10000 non-null object
# card_state                        10000 non-null object
# card_state_enName                 10000 non-null object
# dtypes: datetime64[ns](2), float64(6), int64(13), object(13)
# memory usage: 2.6+ MB

# %%
features = ['purchase_dow']
X = df['']

# %%
model = RandomForestClassifier()
model.fit(X, y)

today = datetime.date.today()
filename = 'model_{}-{}-{}.pkl'.format(today.year, today.month, today.day)

model_folder = dataiku.Folder("model_folder")
with model_folder.get_writer(filename) as w:
    pickle.dump(model, w)

# %%
# Write recipe outputs
model_folder = dataiku.Folder("ztzpRjao")
model_folder_info = model_folder.get_info()
