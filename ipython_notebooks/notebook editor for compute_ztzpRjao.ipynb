# %%
# -*- coding: utf-8 -*-
import dataiku
import pandas as pd
import numpy as np
import datetime
import pickle
from sklearn.ensemble import RandomForestClassifier

# %%
# Read recipe inputs
transactions_known = dataiku.Dataset("transactions_known")
df = transactions_known.get_dataframe(limit=10000)

# %%
df.head()
# Out:
#    transaction_id  authorized_flag        purchase_date purchase_date_parsed  purchase_year  purchase_month  purchase_day  purchase_dow  purchase_weekend  purchase_hour          card_id      merchant_id  merchant_category_id item_category  purchase_amount  signature_provided card_first_active_month card_first_active_month_parsed  days_active card_reward_program  card_latitude  card_longitude  card_fico_score  card_age merchant_subsector_description  merchant_latitude  merchant_longitude       merchant_location  merchant_cardholder_distance merchant_state merchant_state_enName           card_location    card_state card_state_enName
# 0          137156                1  2017-09-02 21:17:33  2017-09-02 21:17:33           2017               9             2             6                 1             21  C_ID_374e4fa3d2  M_ID_e86abc8b2d                   607             A           146.71                   0                 2017-02                     2017-02-01          213           cash_back         48.613        -101.242              452        32                 retail apparel             34.627            -107.053  POINT(-107.053 34.627)                       1011.13     New Mexico            New Mexico  POINT(-101.242 48.613)  North Dakota      North Dakota
# 1          137157                0  2017-09-02 21:18:13  2017-09-02 21:18:13           2017               9             2             6                 1             21  C_ID_ad08a5f4da  M_ID_3973c9b4da                   422             B           338.59                   0                 2017-08                     2017-08-01           32           cash_back         38.162         -76.946              407        21           consumer electronics             38.314            -122.724  POINT(-122.724 38.314)                       2458.12     California            California   POINT(-76.946 38.162)      Virginia          Virginia
# 2          137161                1  2017-09-02 21:19:18  2017-09-02 21:19:18           2017               9             2             6                 1             21  C_ID_b83affec2c  M_ID_617112f30e                   299             B            34.40                   0                 2017-08                     2017-08-01           32           cash_back         40.662         -79.263              720        69                   luxury goods             38.590            -101.627   POINT(-101.627 38.59)                       1195.47         Kansas                Kansas   POINT(-79.263 40.662)  Pennsylvania      Pennsylvania
# 3          137163                1  2017-09-02 21:20:58  2017-09-02 21:20:58           2017               9             2             6                 1             21  C_ID_be6dc33629  M_ID_b1b875d9b2                   457             D            34.40                   0                 2016-05                     2016-05-01          489           cash_back         37.251         -89.510              706        23                   luxury goods             41.767            -110.482  POINT(-110.482 41.767)                       1157.40        Wyoming               Wyoming    POINT(-89.51 37.251)      Missouri          Missouri
# 4          137164                1  2017-09-02 21:22:20  2017-09-02 21:22:20           2017               9             2             6                 1             21  C_ID_b65f2c70b2  M_ID_a9d91682ad                   506             D           119.69                   1                 2016-10                     2016-10-01          336           cash_back         38.998         -96.319              634        49                         dental             43.578             -72.429   POINT(-72.429 43.578)                       1275.15        Vermont               Vermont   POINT(-96.319 38.998)        Kansas            Kansas

# %%
df.dropna(inplace=True)

# %%
features = ['purchase_month','purchase_dow','purchase_hour','merchant_category_id','purchase_amount','days_active',
            'card_fico_score','card_age','merchant_cardholder_distance']
target = 'authorized_flag'

X = df[features].values
y = df[target]

# %%
model = RandomForestClassifier()
model.fit(X, y)
# Out:
# /Users/katiegross/dataiku/10.0.2/python36.packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
today = datetime.date.today()
filename = 'model_{}-{}-{}.pkl'.format(today.year, today.month, today.day)

model_folder = dataiku.Folder("model")
with model_folder.get_writer(filename) as w:
    pickle.dump(model, w)
# Out:
# ERROR:root:Pipe to generator thread failed
# Traceback (most recent call last):
#   File "/Users/katiegross/dataiku/10.0.2/python36.packages/requests/adapters.py", line 472, in send
#     low_conn.send(i)
#   File "/Users/katiegross/.pyenv/versions/3.6.8/lib/python3.6/http/client.py", line 986, in send
#     self.sock.sendall(data)
# OSError: [Errno 41] Protocol wrong type for socket
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/katiegross/dataiku/10.0.2/python/dataiku/core/dkuio.py", line 244, in run
#     self.consumer(self._generate())
#   File "/Users/katiegross/dataiku/10.0.2/python/dataiku/core/managed_folder.py", line 42, in upload_call
#     }, data=g)
#   File "/Users/katiegross/dataiku/10.0.2/python/dataiku/core/intercom.py", line 440, in jek_or_backend_void_call
#     return backend_void_call(path, data, err_msg, **kwargs)
#   File "/Users/katiegross/dataiku/10.0.2/python/dataiku/core/intercom.py", line 431, in backend_void_call
#     return _handle_void_resp(backend_api_post_call(path, data, **kwargs), err_msg = err_msg)
#   File "/Users/katiegross/dataiku/10.0.2/python/dataiku/core/intercom.py", line 361, in backend_api_post_call
#     **kwargs)
#   File "/Users/katiegross/dataiku/10.0.2/python36.packages/requests/sessions.py", line 581, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "/Users/katiegross/dataiku/10.0.2/python36.packages/requests/sessions.py", line 533, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/katiegross/dataiku/10.0.2/python36.packages/requests/sessions.py", line 646, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/katiegross/dataiku/10.0.2/python36.packages/requests/adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: [Errno 41] Protocol wrong type for socket
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-30112a63510f> in <module>()
#       4 model_folder = dataiku.Folder("model")
#       5 with model_folder.get_writer(filename) as w:
# ----> 6     pickle.dump(model, w)
#
# /Users/katiegross/dataiku/10.0.2/python/dataiku/core/managed_folder.py in __exit__(self, type, value, traceback)
#      56
#      57     def __exit__(self, type, value, traceback):
# ---> 58         self.close()
#      59
#      60 def _folder_writer_atexit_handler():
#
# /Users/katiegross/dataiku/10.0.2/python/dataiku/core/managed_folder.py in close(self)
#      49         if ManagedFolderWriter.active_writers.get(self.full_name) == self:
#      50             del ManagedFolderWriter.active_writers[self.full_name]
# ---> 51         self.piping_thread.close()
#      52         self.piping_thread.wait_for_completion()
#      53
#
# /Users/katiegross/dataiku/10.0.2/python/dataiku/core/dkuio.py in close(self)
#     215         self._check_health()
#     216         self.flush()
# --> 217         self.queue.put(self.end_mark)
#     218
#     219     def wait_for_completion(self):
#
# AttributeError: 'NoneType' object has no attribute 'put'

# %%
# Write recipe outputs
# model_folder = dataiku.Folder("ztzpRjao")
# model_folder_info = model_folder.get_info()
